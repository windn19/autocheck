# %% [markdown]
# <a href="https://colab.research.google.com/github/windn19/autocheck/blob/main/baseblock/lessontwo/%D0%9F%D1%80%D0%BE%D0%B2%D0%B5%D1%80%D0%BA%D0%B0_%22%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B1%D0%BB%D0%BE%D0%BA_%7C_%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B8_Numpy_%D0%B8_Matplotlib_%7C_%D0%94%D0%97_Ultra_Pro_(%D0%A0%D0%B0%D0%B7%D0%B1%D0%BE%D1%80)_%7C_%D0%A3%D0%98%D0%981.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнее задание

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Напишите функцию **prod_matrix_3** для матричного умножения трёх матриц без использования встроенных средств `np.dot()`, **@**.

# %%
import numpy as np
matrix1 = np.random.randint(0, 12, (4,3))  
matrix2 = np.random.randint(12, 24, (3,4))  
matrix3 = np.random.randint(24, 46, (4,2))

# %%
# Функция матричного умножения, принимающая на вход 2 матрицы
def prod_matrix(matrix1, matrix2):
    shape1 = matrix1.shape                # Размерность первой матрицы
    shape2 = matrix2.shape                # Размерность второй матрицы
    # Если количество столбцов первой матрицы не равно количеству строк второйой матрицы
    if (shape1[1] != shape2[0]): 
        return np.array([])               # Возвращаем пустой массив
    
    # Создание матрицы из 0, размерности (количество строк первой) x (количество столбцов второй) матриц
    out_matrix = np.zeros((shape1[0], shape2[1])) 

    for i in range(shape1[0]):            # Для индексов строк первой матрицы
        for j in range(shape2[1]):        # Для индексов столбцов второй матрицы
            for t in range(shape1[1]):    # Для индексов стобцов первой матрицы
                # Подсчет суммы произведения элементов строки первой матрицы и столбцов второй матрицы
                out_matrix[i, j] += matrix1[i,t] * matrix2[t,j] 
  
    return out_matrix 

# Функция перемножения трех матриц
def prod_matrix_3(matrix1, matrix2, matrix3):
    # Перемножение матриц слева направо
    return prod_matrix(prod_matrix(matrix1, matrix2), matrix3)

# %%
def prod_matrix_3(matrix1, matrix2, matrix3):
  return matrix1@matrix2@matrix3

# %%
def prod_matrix_3(matrix1, matrix2, matrix3):
  return matrix1.dot(matrix2).dot(matrix3)

# %%
def prod_matrix_3(matrix1, matrix2, matrix3)
  return matrix1.dot(matrix2).dot(matrix3)
# Out:
#   File "<ipython-input-5-aa4c0ee6c605>", line 1
#     def prod_matrix_3(matrix1, matrix2, matrix3)
#                                                 ^
# SyntaxError: invalid syntax

# %%
# Вывод трех матриц и их произведения
print(matrix1,'\n')
print(matrix2,'\n')
print(matrix3,'\n')
print(prod_matrix_3(matrix1, matrix2, matrix3))

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Создайте функцию **whirligig**, которая принимает на вход размер N квадратной матрицы, а выдает матрицу размером N*N, заполненную числами натурального ряда, начиная с первого элемента и двигаясь по спирали:
#
# ---
#
# В зависимости от введенных данных результат может выглядеть так:
#
# ![image.png](data:image/png;base64,...)

# %%
# Запрос размерности матрицы n x n
n = int(input("Размерность квадратной матрицы: "))
# Результирующая матрица
mat = [[0]*n for i in range(n)]
# st - текущее значение-счетчик для записи в матрицу
# m - коеффициент, используемый для заполнения верхней
# матрицы последующих витков, т.к. одномерные матрицы
# следующих витков имеют меньше значений
st, m = 1, 0
# Определение центрального элемента матрицы
mat[n//2][n//2]=n*n
for v in range(n//2):
    # Заполнение верхней горизонтали матрицы
    for i in range(n-m):
        mat[v][i+v] = st
        st+=1
    # Заполнение правой вертикали матрицы    
    for i in range(v+1, n-v):
        mat[i][-v-1] = st
        st+=1
    # Заполнение нижней горизонтали матрицы
    for i in range(v+1, n-v):
        mat[-v-1][-i-1] =st
        st+=1      
    # Заполнение левой вертикали матрицы
    for i in range(v+1, n-(v+1)):
        mat[-i-1][v]=st
        st+=1
    m+=2
# Вывод результата на экран
for i in mat:
    print(*i)

# %%
def whirligig(n):
  mat = [[0]*n for i in range(n)]
  # st - текущее значение-счетчик для записи в матрицу
  # m - коеффициент, используемый для заполнения верхней
  # матрицы последующих витков, т.к. одномерные матрицы
  # следующих витков имеют меньше значений
  st, m = 1, 0
  # Определение центрального элемента матрицы
  mat[n//2][n//2]=n*n
  for v in range(n//2):
      # Заполнение верхней горизонтали матрицы
      for i in range(n-m):
          mat[v][i+v] = st
          st+=1
      # Заполнение правой вертикали матрицы    
      for i in range(v+1, n-v):
          mat[i][-v-1] = st
          st+=1
      # Заполнение нижней горизонтали матрицы
      for i in range(v+1, n-v):
          mat[-v-1][-i-1] =st
          st+=1      
      # Заполнение левой вертикали матрицы
      for i in range(v+1, n-(v+1)):
          mat[-i-1][v]=st
          st+=1
      m+=2
  return mat

# %%
def whirligig(n):
  mat = [[0]*n for i in range(n)]
  # st - текущее значение-счетчик для записи в матрицу
  # m - коеффициент, используемый для заполнения верхней
  # матрицы последующих витков, т.к. одномерные матрицы
  # следующих витков имеют меньше значений
  st, m = 1, 0
  # Определение центрального элемента матрицы
  mat[n//2][n//2]=n*n
  for v in range(n//2):
      # Заполнение верхней горизонтали матрицы
      for i in range(n-m):
          mat[v][i+v] = st
          st+=1
      # Заполнение правой вертикали матрицы    
      for i in range(v+1, n-v):
          mat[i][-v-1] = st
          st+=1
      # Заполнение нижней горизонтали матрицы
      for i in range(v+1, n-v):
          mat[-v-1][-i-1] =st
          st+=1      
      # Заполнение левой вертикали матрицы
      for i in range(v+1, n-(v+1)):
          mat[-i-1][v]=st
          st+=1
      m+=2
  return m

# %%
def whirligig1(n):
  mat = [[0]*n for i in range(n)]
  # st - текущее значение-счетчик для записи в матрицу
  # m - коеффициент, используемый для заполнения верхней
  # матрицы последующих витков, т.к. одномерные матрицы
  # следующих витков имеют меньше значений
  st, m = 1, 0
  # Определение центрального элемента матрицы
  mat[n//2][n//2]=n*n
  for v in range(n//2):
      # Заполнение верхней горизонтали матрицы
      for i in range(n-m):
          mat[v][i+v] = st
          st+=1
      # Заполнение правой вертикали матрицы    
      for i in range(v+1, n-v):
          mat[i][-v-1] = st
          st+=1
      # Заполнение нижней горизонтали матрицы
      for i in range(v+1, n-v):
          mat[-v-1][-i-1] =st
          st+=1      
      # Заполнение левой вертикали матрицы
      for i in range(v+1, n-(v+1)):
          mat[-i-1][v]=st
          st+=1
      m+=2
  return mat

# %%
whirligig(3)

# %%
whirligig(6)

# %% [markdown]
# ### Задача 3

# %% [markdown]
# Используя библиотеку `numpy` напишите функцию **work_days**, которая будет принимать на вход две стоки - начало периода и конец периода в формате ('2015-02', '2015-03'), а на выходе будет количество будних дней в указанный период.
#
# ---
#
# Ваш результат может выглядеть так:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# При решении задания вам может пригодиться метод numpy.busday_count()
#
# ---
# Дополнительная информация ([База знаний УИИ - «**Функции DateTime в Numpy**»](https://colab.research.google.com/drive/1gSg4eZkpGwP0Zs5VGhl8uMhoo2Gmsil6?usp=sharing))
#
# ---

# %%
print("Количество будних дней в феврале 2015 года: ")
print(np.busday_count('2015-02', '2015-03'))

# %%
import numpy as np

# %%
def work_days(start, end):
  return np.busday_count(start, end)

# %%
work_days('2021-03', '2021-04')

# %% [markdown]
# ### Задача 4

# %% [markdown]
# Создайте гистограмму, содержащую различные варианты текстур, сохранненных с списке **patterns**
#
# ---
#
# В зависимости от введенных данных результат может выглядеть так:
#
# ![image.png](data:image/png;base64,...)

# %%
# Создание графика
fig = plt.figure()
# Варианты текстур
patterns = [ "|" , "\\" , "/" , "+" , "-", ".", "*","x", "o", "O" ]
# Разделение на области
ax = fig.add_subplot(111)
# Перебор текстур
for i in range(len(patterns)):
    # Отрисовка гистограммы
    ax.bar(i, 3, color='red', edgecolor='white', hatch=patterns[i])
plt.show()

# %%
patterns = [ "|" , "\\" , "/" , "+" , "-", ".", "*","x", "o", "O" ]
for num, i in enumerate(patterns):
  plt.bar(num, 3, color='red', edgecolor='white', hatch=i)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(range(10), [3]*10, color='red', edgecolor='white', hatch=patterns)
plt.show()

# %% [markdown]
# ### Задача 5

# %% [markdown]
# Постройте точечную диаграмму с использованием случайных распределений для создания шариков разных размеров.
# Определите несколько списков:
#  * x - координата по абциссе
#  * y - координата по ординате
#  * colors - цвета кругов
#  * areas - размеры кругов
#
# и с их помощью постройте точечную диаграмму.
#
# ---
#
# В зависимости от введенных данных результат может выглядеть так:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# При решении задания вам может пригодиться метод `plt.scatter()`
#
# ---
# Дополнительная информация ([База знаний УИИ - «**Scatter - график разброса**»](https://colab.research.google.com/drive/1DvReBj0GxdwVaQ72WUleiIwQGer1-vfn?usp=sharing))
#
# ---

# %%
import math
import random
# Количество шариков
no_of_balls = 100
# Значения по оси Х с плавающей точкой
x = [random.triangular() for i in range(no_of_balls)]
# Значения по оси Y, случайные числа на основе распределения Гаусса
y = [random.gauss(0.5, 0.25) for i in range(no_of_balls)]
# Цвета кругов
colors = [random.randint(1, 4) for i in range(no_of_balls)]
# Генерация кругов
areas = [math.pi * random.randint(5, 15)**2 for i in range(no_of_balls)]
# Отрисовка графика
plt.figure()
# Создание точечного графика
plt.scatter(x, y, s=areas, c=colors, alpha=0.85)
# Значения осей
plt.axis([0.0, 1.0, 0.0, 1.0])
# Подписи осей
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# Здесь необходимо разместить текст ДЗ с решением

# %% [markdown]
# # **Проверка ДЗ**

# %% [markdown]
# 1. В ячейке ниже необходимо заменить `from terra_autocheck.baseblock.lessonone import light` на модуль Вашего ДЗ. Например для уровня ПРО занятия "Введение в НС", подключение библиотеки будет выглядеть следующим образом:
#
#         from terra_autocheck.baseblock.lessonthree import pro

# %% [markdown]
# 2. Вызвать функцию автопроверки:
#
#         Autocheck.Start(1739, globals())
#
# 1739 - это ID вашего ДЗ. Необходимо заменить на ID вашей домашки (можно найти в скрипте репозитория вашего ДЗ)

# %%
#@title Запустите ячейку для начала проверки <br> <h6>
# !rm -rf terra_autocheck
# !git clone -q https://github.com/gitterra/terra_autocheck.git
from terra_autocheck import Autocheck
from terra_autocheck.baseblock.lessontwo import ultraPro

Autocheck.Start(1745, globals())
# Out:
# Задание : 100%|██████████  5/5
#  Задание 1 выполнено
#
#
#  Задание 2 выполнено
#
#
#  Задание 3 выполнено
#
#
#  Задание 4 выполнено
#
#
#  Задание 5 выполнено
#
#
# ДЗ выполнено
